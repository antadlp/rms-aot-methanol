# %% [markdown]
# <img src='buildOfRMs.png'>

# %% [markdown]
# # 1.0 - Which molecules were used?

# %% [markdown]
# The molecules of the systems that were studied were chosen considering reverse micelles (RMs) coexisting with alcohols. We chose AOT/isooctane/water for the RMs, which is the most common combination, and methanol for the alcohol.

# %% [markdown]
# ## 1.1 - AOT

# %% [markdown]
# Aerosol OT (sodium diethylhexyl sulfosuccinate, sodium docusate, AOT) is the most used surfactant for its efficiency.[[1]](https://doi.org/10.1021/cr200254q)[[2]](https://doi.org/10.1021/la000342i). It has the following structure

# %% [markdown]
# ### 1.1.1 AOT structure (nglview)

# %%
import nglview as nv

PATH_AOT = "../data/pdbs/63UD_allatom_optimised_geometry.pdb"

view = nv.show_file(PATH_AOT)
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# ### 1.1.2 AOT structure (image)

# %% [markdown]
# <img src="..\imgs\nglview-aot.png" width=200>
